# %% [markdown]
# # id추가

# %%
import pandas as pd
dataset = pd.read_csv(r"C:\Users\jmlee\Desktop\kakao_arena\csv_jimin\song_artist_tag.csv")  
dataset.drop(['Unnamed: 0'], axis='columns', inplace=True)
dataset
# Out:
#                                                 song_name  \
# 0            Itshouni... (함께...) (Groove That Soul Remix)
# 1                           Hare Tokidoki Yuki (맑음 때때로 눈)
# 2        Schumann : Waldszenen Op.82 - I. Eintritt (슈만...
# 3                     Yasashii Kisswo Shite (부드러운 키스를 해줘)
# 4               Yokohama Fall In Love (요코하마 Fall In Love)
# ...                                                   ...
# 490557                                          ｅｎｄｕｒａｎｃｅ
# 490558                                             ｓｐｒｘｎｇ
# 490559                                               ｘｐｋｔ
# 490560                                     ￥entertainment
# 490561               ￦ON IT ALL (Feat. Most Badass Asian)
#
#           artist_name_basket  \
# 0                    ['Max']
# 1               ['Depapepe']
# 2       ['Martin Stadtfeld']
# 3       ['DREAMS COME TRUE']
# 4              ['Hino Mika']
# ...                      ...
# 490557        ['Invention_']
# ...

# %%
import pandas as pd
dataset1 = pd.read_csv(r"C:\Users\jmlee\Desktop\kakao_arena\csv_data\song_meta.csv")
dataset1.drop(['Unnamed: 0','Unnamed: 10','Unnamed: 11','Unnamed: 12'], axis='columns', inplace=True)
genre=dataset1[['song_gn_gnr_basket','song_name','artist_name_basket']]
# Out:
# C:\Users\jmlee\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (4,9,10,11) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
dataset1
# Out:
#        song_gn_dtl_gnr_basket  issue_date  \
# 0                  ['GN0901']    20140512
# 1        ['GN1601', 'GN1606']    20080421
# 2                  ['GN0901']    20180518
# 3        ['GN1102', 'GN1101']    20151016
# 4        ['GN1802', 'GN1801']    20110824
# ...                       ...         ...
# 707984             ['GN2001']    19991219
# 707985             ['GN0901']    19860000
# 707986   ['GN0105', 'GN0101']    20160120
# 707987   ['GN1807', 'GN1801']    20131217
# 707988   ['GN0601', 'GN0604']    19980000
#
#                                                album_name     album_id  \
# 0                            불후의 명곡 - 7080 추억의 얄개시대 팝송베스트  2.25564e+06
# 1                           Bach : Partitas Nos. 2, 3 & 4       376431
# 2                                                     Hit  4.69875e+06
# 3       Feeling Right (Everything Is Nice) (Feat. Popc...  2.64488e+06
# 4                                                 그남자 그여자  2.00847e+06
# ...

# %%
#노래, 가수, 장르, 태그 합친 df
#merge로 합치기. 같은 노래여도 다른 앨범이름을 가지고 있는 경우 있음.(발행일, 앨범이름, id다름)
df=pd.merge(dataset1, dataset)  
df
# Out:
#        song_gn_dtl_gnr_basket  issue_date  \
# 0                  ['GN0901']    20140512
# 1                  ['GN0901']    20140122
# 2                  ['GN0901']    20180518
# 3        ['GN1004', 'GN1001']    20140101
# 4        ['GN1102', 'GN1101']    20151016
# ...                       ...         ...
# 572580   ['GN1502', 'GN1501']    20080929
# 572581   ['GN1701', 'GN1702']    20180427
# 572582             ['GN2001']    19991219
# 572583   ['GN0105', 'GN0101']    20160120
# 572584   ['GN0601', 'GN0604']    19980000
#
#                                                album_name     album_id  \
# 0                            불후의 명곡 - 7080 추억의 얄개시대 팝송베스트  2.25564e+06
# 1                                응답하라 7080 (추억의 빈티지 팝송여행)      2228365
# 2                                                     Hit  4.69875e+06
# 3                                                  R-Kive      2284081
# 4       Feeling Right (Everything Is Nice) (Feat. Popc...  2.64488e+06
# ...

# %%
df.to_csv('song_artist_genre_toptags_id.csv')

# %%
df=df[['issue_date','song_gn_gnr_basket','song_name','artist_name_basket','top_tags','id']]
df
# Out:
#         issue_date song_gn_gnr_basket  \
# 0         20140512         ['GN0900']
# 1         20140122         ['GN0900']
# 2         20180518         ['GN0900']
# 3         20140101         ['GN1000']
# 4         20151016         ['GN1100']
# ...            ...                ...
# 572580    20080929         ['GN1500']
# 572581    20180427         ['GN1700']
# 572582    19991219         ['GN2000']
# 572583    20160120         ['GN0100']
# 572584    19980000         ['GN0600']
#
#                                                 song_name  \
# 0                                                Feelings
# 1                                                Feelings
# 2                         Solsbury Hill (Remastered 2002)
# 3                         Solsbury Hill (Remastered 2002)
# 4       Feeling Right (Everything Is Nice) (Feat. Popc...
# ...                                                   ...
# 572580                                     밤차 (Feat. 신민아)
# ...

# %%
#중복값 제거
df=df.drop_duplicates()
df
# Out:
#         issue_date song_gn_gnr_basket  \
# 0         20140512         ['GN0900']
# 1         20140122         ['GN0900']
# 2         20180518         ['GN0900']
# 3         20140101         ['GN1000']
# 4         20151016         ['GN1100']
# ...            ...                ...
# 572580    20080929         ['GN1500']
# 572581    20180427         ['GN1700']
# 572582    19991219         ['GN2000']
# 572583    20160120         ['GN0100']
# 572584    19980000         ['GN0600']
#
#                                                 song_name  \
# 0                                                Feelings
# 1                                                Feelings
# 2                         Solsbury Hill (Remastered 2002)
# 3                         Solsbury Hill (Remastered 2002)
# 4       Feeling Right (Everything Is Nice) (Feat. Popc...
# ...                                                   ...
# 572580                                     밤차 (Feat. 신민아)
# ...

# %%
df  #대분류,노래이름,가수,태그,id 모음
# Out:
#         issue_date song_gn_gnr_basket  \
# 0         20140512         ['GN0900']
# 1         20140122         ['GN0900']
# 2         20180518         ['GN0900']
# 3         20140101         ['GN1000']
# 4         20151016         ['GN1100']
# ...            ...                ...
# 572580    20080929         ['GN1500']
# 572581    20180427         ['GN1700']
# 572582    19991219         ['GN2000']
# 572583    20160120         ['GN0100']
# 572584    19980000         ['GN0600']
#
#                                                 song_name  \
# 0                                                Feelings
# 1                                                Feelings
# 2                         Solsbury Hill (Remastered 2002)
# 3                         Solsbury Hill (Remastered 2002)
# 4       Feeling Right (Everything Is Nice) (Feat. Popc...
# ...                                                   ...
# 572580                                     밤차 (Feat. 신민아)
# ...
